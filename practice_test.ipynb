# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from IPython.core.interactiveshell import InteractiveShell

# %%
InteractiveShell.ast_node_interactivity = "all"

# %%
df=pd.read_csv('StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
pd.crosstab(df['gender'],df['lunch'])
# Out:
# lunch   free/reduced  standard
# gender
# female           189       329
# male             166       316

# %% [markdown]
# gender distribution is almost same

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df['race/ethnicity'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='race/ethnicity'>

# %% [markdown]
# middle raced students are more there

# %%
par=df['parental level of education'].value_counts()
par
#df['par_count']=df['parental level of education'].value_counts()
df['parental level of education'].value_counts().plot(kind='pie',autopct='%.1f')
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64
# <Axes: ylabel='count'>

# %% [markdown]
# below code was just like that...nothing insight-related

# %%
#df.pivot_table(values='par_count',index='')
# d1=df[['par_count','race/ethnicity','math score']]
d1=df[['race/ethnicity','math score']]
d1
# plt.hist(df[['math score']])
#d1.pivot_table(values='par_count', index='race/ethnicity', columns='gender')
# Out:
#     race/ethnicity  math score
# 0          group B          72
# 1          group C          69
# 2          group B          90
# 3          group A          47
# 4          group C          76
# ..             ...         ...
# 995        group E          88
# 996        group C          62
# 997        group C          59
# 998        group D          68
# 999        group D          77
#
# [1000 rows x 2 columns]

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   race/ethnicity  1000 non-null   object
#  1   math score      1000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %% [markdown]
# score in all is almost same...with reading leading a bit and maths at the back

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
df['test preparation course'].value_counts()
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %% [markdown]
# seeming that getting standard lunch makes students score better

# %%
sns.distplot(df[df['lunch']=='standard']['math score'],hist=False)
sns.distplot(df[df['lunch']=='free/reduced']['math score'],color='green',hist=False)
# Out:
# /tmp/ipython-input-3649354593.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['lunch']=='standard']['math score'],hist=False)
# <Axes: xlabel='math score', ylabel='Density'>
# /tmp/ipython-input-3649354593.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.distplot(df[df['lunch']=='standard']['reading score'],hist=False)
sns.distplot(df[df['lunch']=='free/reduced']['reading score'],color='green',hist=False)
# Out:
# /tmp/ipython-input-4250952709.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['lunch']=='standard']['reading score'],hist=False)
# <Axes: xlabel='reading score', ylabel='Density'>
# /tmp/ipython-input-4250952709.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.distplot(df[df['lunch']=='standard']['writing score'],hist=False)
sns.distplot(df[df['lunch']=='free/reduced']['writing score'],color='green',hist=False)
# Out:
# /tmp/ipython-input-656257937.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['lunch']=='standard']['writing score'],hist=False)
# <Axes: xlabel='writing score', ylabel='Density'>
# /tmp/ipython-input-656257937.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.distplot(df[df['gender']=='male']['math score'],hist=False)
sns.distplot(df[df['gender']=='female']['math score'],color='green',hist=False)
# Out:
# /tmp/ipython-input-781736777.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['gender']=='male']['math score'],hist=False)
# <Axes: xlabel='math score', ylabel='Density'>
# /tmp/ipython-input-781736777.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(df[df['gender']=='male']['reading score'],hist=False)
sns.distplot(df[df['gender']=='female']['reading score'],color='green',hist=False)
# Out:
# /tmp/ipython-input-3036369436.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['gender']=='male']['reading score'],hist=False)
# <Axes: xlabel='reading score', ylabel='Density'>
# /tmp/ipython-input-3036369436.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.distplot(df[df['gender']=='male']['writing score'],hist=False)
sns.distplot(df[df['gender']=='female']['writing score'],color='green',hist=False)
# Out:
# /tmp/ipython-input-1075841831.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['gender']=='male']['writing score'],hist=False)
# <Axes: xlabel='writing score', ylabel='Density'>
# /tmp/ipython-input-1075841831.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# except in maths...boys are behind girls in other scores

# %%
sns.boxplot(data=df, x="race/ethnicity", y="math score")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='math score'>

# %%
df.sample(7)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 479    male        group E          associate's degree      standard
# 6    female        group B                some college      standard
# 718  female        group C                 high school      standard
# 517  female        group E                some college      standard
# 257    male        group C          associate's degree      standard
# 419    male        group E                 high school  free/reduced
# 165  female        group C           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 479                    none          76             71             67
# 6                 completed          88             95             92
# 718                    none          76             76             74
# 517               completed          66             74             73
# ...

# %%
sns.distplot(df[df['test preparation course']=='none']['writing score'],hist=False)
sns.distplot(df[df['test preparation course']=='completed']['writing score'],color='green',hist=False)
# Out:
# /tmp/ipython-input-1234807768.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['test preparation course']=='none']['writing score'],hist=False)
# <Axes: xlabel='writing score', ylabel='Density'>
# /tmp/ipython-input-1234807768.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.boxplot(data=df, x="parental level of education", y="math score")
# Out:
# <Axes: xlabel='parental level of education', ylabel='math score'>
